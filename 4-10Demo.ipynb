# %%
load("SHPChaos.sage")

# %%
julia_plot(interact = True)
# Out:
# interactive(children=(FloatSlider(value=-1.0, description='Real c', max=2.0, min=-2.0, step=1e-05), FloatSlide…

# %%
external_ray([1/3,2/3])
# Out:
# 500x500px 24-bit RGB image

# %%
c = -0.75
qs = [1/3, 2/3]
rays = external_ray_points(c,qs)
ray_plots = [list_plot(r, plotjoined = True, color = 'white', thickness = 10) for r in rays]
pt = point((-0.75,0), color = 'green', size = 800)
z = var('z')
plot_with_julia(pt + ray_plots[0] + ray_plots[1], z^2 + c)
# Out:
# <PIL.Image.Image image mode=RGBA size=500x500 at 0x7F2D38627A00>

# %%
c = -1.125+0.2165*I
qs = [11/63, 22/63, 44/63, 25/63, 50/63, 37/63]
rays = external_ray_points(c,qs)
ray_plots = [list_plot(r, plotjoined = True, color = 'white', thickness = 10) for r in rays]
pt = point((-1.125,0.2165), color = 'red', size = 800)
z = var('z')
plot_with_julia(pt + sum(ray_plots[i] for i in range(6)), z^2 + c)
# Out:
# <PIL.Image.Image image mode=RGBA size=500x500 at 0x7F2D3A796D90>

# %%
plot_with_julia(pt + ray_plots[1] + ray_plots[3], z^2 + c, pixel_count = 1000) # Here we pick out the angles 22/63 and 25/63
# Out:
# <PIL.Image.Image image mode=RGBA size=1000x1000 at 0x7F2D385F8550>

# %%
external_ray([22/63, 25/63, 1/3, 2/3])
# Out:
# 500x500px 24-bit RGB image
